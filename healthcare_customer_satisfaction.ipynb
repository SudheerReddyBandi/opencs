# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
Training1 = pd.read_csv("drive/MyDrive/drugsComTrain_raw.csv")

# %%
Training1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161297 entries, 0 to 161296
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     161297 non-null  int64
#  1   drugName     161297 non-null  object
#  2   condition    160398 non-null  object
#  3   review       161297 non-null  object
#  4   rating       161297 non-null  int64
#  5   date         161297 non-null  object
#  6   usefulCount  161297 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 8.6+ MB

# %%
Training1.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  161297.000000  161297.000000  161297.000000
# mean   115923.585305       6.994377      28.004755
# std     67004.445170       3.272329      36.403742
# min         2.000000       1.000000       0.000000
# 25%     58063.000000       5.000000       6.000000
# 50%    115744.000000       8.000000      16.000000
# 75%    173776.000000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['uniqueID'].plot(kind='hist', bins=20, title='uniqueID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_7['usefulCount'].plot(kind='line', figsize=(8, 4), title='usefulCount')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_6['rating'].plot(kind='line', figsize=(8, 4), title='rating')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_5['uniqueID'].plot(kind='line', figsize=(8, 4), title='uniqueID')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_4.plot(kind='scatter', x='rating', y='usefulCount', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3.plot(kind='scatter', x='uniqueID', y='rating', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_2['usefulCount'].plot(kind='hist', bins=20, title='usefulCount')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['rating'].plot(kind='hist', bins=20, title='rating')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['uniqueID'].plot(kind='hist', bins=20, title='uniqueID')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from matplotlib import pyplot as plt
stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, width = 1200, height = 800).generate(str(Training1['drugName']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - Drug Names', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, width = 1200, height = 800).generate(str(Training1['condition']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - Condition', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
mh= Training1[Training1['condition'].isin(["depression","COPD, Maintenance","ADHD", "Depression","anxiety","Anxiety","Bipolar Disorde","Epilepsy","Bipolar Disorde","Panic Disorde", "Anxiety and Stress", "Major Depressive Disorde","Generalized Anxiety Disorde","Night Terrors","Post Traumatic Stress Disorde","Obsessive Compulsive Disorde","Schizoaffective Disorde","panic disorder","depression/ anxiety","depression and generalized anxiety","anxiety/ ocpd /depression","OCPD","OCD","ocd","panic attacks and depression","generalized anxiety disorder","anxiety and to avoid feeling misrable","anxiety/ mild depression","bipolar","restless sleep","sleep problem","depression/anxiety","hot flash sleep problems","depression,irritability","severe depression","depression/difficulty sleeping","insomnia","bi-polar mania with anger issues","anxiety insomnia","bipolar disorder / insomnia","depression/panic disorder","anxiety and depression","depression; intrusive suicidal impulses","fatigue","depression, ptsd fatigue","anxiety, panic attck, nervousness","irritability,anxiety","social anxiety","severe insomnia","bipolar disorder ii","bipolar i","depression, anxiety, ocd, nausea","insomnia, bipolar","fatigue,depression","insomnia, migraines","bi-polar 2","clinical depression","psychosis","Psychosis","Posttraumatic stress disorder","recurrent depression","stress-related anxiety","depression, tension headache","depression, a.d.d., mood instability","depression (atypical)","Insomnia"])]

# %%
print(type(mh))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(mh.head(4))
# Out:
#     uniqueID        drugName        condition  \
# 1      95260      Guanfacine             ADHD
# 7     102654    Aripiprazole  Bipolar Disorde
# 8      74811          Keppra         Epilepsy
# 11     75612  L-methylfolate       Depression
#
#                                                review  rating       date  \
# 1   "My son is halfway through his fourth week of ...       8  27-Apr-10
# 7   "Abilify changed my life. There is hope. I was...      10  14-Mar-15
# 8   " I Ve had  nothing but problems with the Kepp...       1   9-Aug-16
# 11  "I have taken anti-depressants for years, with...      10   9-Mar-17
#
#     usefulCount
# 1           192
# 7            32
# 8            11
# 11           54

# %%
mh.drop(columns=['uniqueID', 'date','usefulCount'], inplace=True)
# Out:
# <ipython-input-19-77e9b8603ff3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mh.drop(columns=['uniqueID', 'date','usefulCount'], inplace=True)

# %%
print(mh.head())
# Out:
#           drugName        condition  \
# 1       Guanfacine             ADHD
# 7     Aripiprazole  Bipolar Disorde
# 8           Keppra         Epilepsy
# 11  L-methylfolate       Depression
# 18     Lamotrigine  Bipolar Disorde
#
#                                                review  rating
# 1   "My son is halfway through his fourth week of ...       8
# 7   "Abilify changed my life. There is hope. I was...      10
# 8   " I Ve had  nothing but problems with the Kepp...       1
# 11  "I have taken anti-depressants for years, with...      10
# 18  "I&#039;ve been on every medicine under the su...      10

# %%
'''df = pd.DataFrame(students,
                  columns=['Name', 'Age', 'City', 'Country'],
                  index=['a', 'b', 'c', 'd', 'e', 'f'])'''

mh.insert(loc=4,column='effectiveness',value='')
mh.insert(loc=5,column='sideEffects',value='')

# %%
print(mh.head())
# Out:
#           drugName        condition  \
# 1       Guanfacine             ADHD
# 7     Aripiprazole  Bipolar Disorde
# 8           Keppra         Epilepsy
# 11  L-methylfolate       Depression
# 18     Lamotrigine  Bipolar Disorde
#
#                                                review  rating effectiveness  \
# 1   "My son is halfway through his fourth week of ...       8
# 7   "Abilify changed my life. There is hope. I was...      10
# 8   " I Ve had  nothing but problems with the Kepp...       1
# 11  "I have taken anti-depressants for years, with...      10
# 18  "I&#039;ve been on every medicine under the su...      10
#
#    sideEffects
# 1
# 7
# 8
# 11
# 18

# %%
#df['NEW'] = pd.Series(random.choices(['yes','no'], weights=[1, 1], k=len(df), index=df.index)
import random
#mh['effectiveness'] = pd.Series(random.choices(['Highly Effective', 'Marginally Effective', 'Ineffective', 'Considerably Effective', 'Moderately Effective'], weights=[5, 2, 1, 3, 4]))
#mh.loc[mh["rating"] == 10, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Marginally Effective', 'Ineffective', 'Considerably Effective', 'Moderately Effective'], weights=[5, 2, 1, 3, 4],k=len(mh)))

# %%
#mh.loc[mh["rating"] == 9, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Marginally Effective', 'Ineffective', 'Considerably Effective', 'Moderately Effective'], weights=[4, 3, 1, 2, 5],k=len(mh)))

# %%
mh.loc[mh["rating"] == 10, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective', 'Considerably Effective', 'Marginally Effective', 'Ineffective'], weights=[1, 0, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 9, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[1, 0, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 8, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[1, 1, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 7, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[1, 2, 3, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 6, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[1, 2, 3, 3, 0],k=len(mh)))
mh.loc[mh["rating"] == 5, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[0, 1, 2, 3, 0],k=len(mh)))
mh.loc[mh["rating"] == 4, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[0, 1, 2, 3, 4],k=len(mh)))
mh.loc[mh["rating"] == 3, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[0, 0, 1, 2, 3],k=len(mh)))
mh.loc[mh["rating"] == 2, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[0, 0, 0, 1, 2],k=len(mh)))
mh.loc[mh["rating"] == 1, "effectiveness"] = pd.Series(random.choices(['Highly Effective', 'Moderately Effective','Considerably Effective','Marginally Effective', 'Ineffective'], weights=[0, 0, 0, 1, 2],k=len(mh)))

# %%
#[ 'No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects' ]

mh.loc[mh["rating"] == 10, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 0, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 9, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 0, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 8, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 0, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 7, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 1, 0, 0, 0],k=len(mh)))
mh.loc[mh["rating"] == 6, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[5, 4, 3, 2, 1],k=len(mh)))
mh.loc[mh["rating"] == 5, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 4, 5, 2, 3],k=len(mh)))
mh.loc[mh["rating"] == 4, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 2, 3, 5, 4],k=len(mh)))
mh.loc[mh["rating"] == 3, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[1, 2, 3, 4, 5],k=len(mh)))
mh.loc[mh["rating"] == 2, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[0, 0, 0, 1, 1],k=len(mh)))
mh.loc[mh["rating"] == 1, "sideEffects"] = pd.Series(random.choices(['No Side Effects','Moderate Side Effects','Mild Side Effects','Severe Side Effects','Extremely Severe Side Effects'], weights=[0, 0, 0, 1, 1],k=len(mh)))

# %%
print(mh.drugName.unique())
# Out:
# ['Guanfacine' 'Aripiprazole' 'Keppra' 'L-methylfolate' 'Lamotrigine'
#  'Trazodone' 'Daytrana' 'Ativan' 'Sertraline' 'Trilafon' 'Clonazepam'
#  'Venlafaxine' 'Symbyax' 'Intuniv' 'Latuda' 'Effexor XR' 'Wellbutrin'
#  'Lithium' 'Fluoxetine' 'Fluvoxamine' 'Mirtazapine' 'Lamictal' 'Buspirone'
#  'Propranolol' 'Focalin' 'Clomipramine' 'Olanzapine' 'Xanax'
#  'Desvenlafaxine' 'Bupropion' 'Viibryd' 'Trintellix' 'Lurasidone'
#  'Alprazolam' 'Escitalopram' 'Depakote' 'Vyvanse' 'Pristiq'
#  'Levomilnacipran' 'BuSpar' 'Lisdexamfetamine' 'Cymbalta' 'Zoloft'
#  'Amphetamine / dextroamphetamine' 'Carbamazepine' 'Ziprasidone'
#  'Atomoxetine' 'Duloxetine' 'Nardil' 'Saphris' 'Lexapro' 'Seroquel'
#  'Concerta' 'Strattera' 'Quetiapine' 'Methylphenidate' 'Amitriptyline'
#  'Klonopin' 'Citalopram' 'Zolpidem' 'Wellbutrin XL' 'Hydroxyzine'
#  'Ramelteon' 'Focalin XR' 'Diazepam' 'Suvorexant' 'Gabapentin' 'Atarax'
#  'Effexor' 'Zyprexa' 'Ambien' 'Levetiracetam' 'Abilify Discmelt' 'Rexulti'
# ...

# %%
print(mh.drugName.unique().shape)
# Out:
# (347,)

# %%
# This barplot shows the top 20 drugs with the 10/10 rating

# Setting the Parameter
import seaborn as sns


sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh.loc[mh.rating == 10, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20],palette = "Blues_d")

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-27-f771a3c6fe12>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20],palette = "Blues_d")

# %%
# This barplot shows the Top 20 drugs with the 1/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh.loc[mh.rating == 1, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

sns_rating.set_title('Top 20 drugs with 1/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-29-f6bfb280e90e>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

# %%
# This barplot shows the top 20 drugs with the 10/10 rating

# Setting the Parameter
import seaborn as sns


sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh.loc[mh.rating == 10, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20],palette = "Greens_d")

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-10-88580bd25ab5>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20],palette = "Greens_d")

# %%
# making a donut chart to represent share of each ratings

size = [68005, 46901, 36708, 25046, 12547, 10723, 8462, 6671]
colors = ['pink', 'cyan', 'maroon',  'magenta', 'orange', 'navy', 'lightgreen', 'yellow']
labels = "10", "1", "9", "8", "7", "5", "6", "4"

my_circle = plt.Circle((0, 0), 0.7, color = 'white')

plt.rcParams['figure.figsize'] = (10, 10)
plt.pie(size, colors = colors, labels = labels, autopct = '%.2f%%')
plt.axis('off')
plt.title('Pie Chart Representation of Ratings', fontsize = 25)
p = plt.gcf()
plt.gca().add_artist(my_circle)
plt.legend()
plt.show()

# %%
# A countplot of the ratings so we can see the distribution of the ratings
plt.rcParams['figure.figsize'] = [20,8]
sns.set(font_scale = 1.4, style = 'darkgrid')
fig, ax = plt.subplots(1, 2)

sns_1 = sns.countplot(mh['rating'], palette = 'spring', order = list(range(10, 0, -1)), ax = ax[0])
sns_2 = sns.distplot(mh['rating'], ax = ax[1])
sns_1.set_title('Count of Ratings')
sns_1.set_xlabel("Rating")

sns_2.set_title('Distribution of Ratings')
sns_2.set_xlabel("Rating")
# Out:
# <ipython-input-30-e5dffcd3c646>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_1 = sns.countplot(mh['rating'], palette = 'spring', order = list(range(10, 0, -1)), ax = ax[0])
# <ipython-input-30-e5dffcd3c646>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns_2 = sns.distplot(mh['rating'], ax = ax[1])
# Text(0.5, 0, 'Rating')

# %%
# This barplot shows the Top 20 drugs with the 1/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh.loc[mh.rating == 6, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

sns_rating.set_title('Top 20 drugs with 1/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-31-a57032c53914>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

# %%
mh.to_csv('drugsComTrain_MH_raw.csv',index=False)

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'yellow', stopwords = stopwords, width = 1200, height = 800).generate(str(mh['condition']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - Condition', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, width = 1200, height = 800).generate(str(Training1['drugName']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - DrugName', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
import pandas as pd
tsv_file='drive/MyDrive/drugLibTrain_raw.tsv'
csv_table=pd.read_table(tsv_file,sep='\t')
csv_table.to_csv('Training2.csv',index=False)
Training2 = pd.read_csv("Training2.csv")
print(Training2.shape)
Training2.head()
# Out:
# (3107, 9)
#    Unnamed: 0       urlDrugName  rating         effectiveness  \
# 0        2202         enalapril       4      Highly Effective
# 1        3117  ortho-tri-cyclen       1      Highly Effective
# 2        1146           ponstel      10      Highly Effective
# 3        3947          prilosec       3  Marginally Effective
# 4        1951            lyrica       2  Marginally Effective
#
#            sideEffects                               condition  \
# 0    Mild Side Effects  management of congestive heart failure
# 1  Severe Side Effects                        birth prevention
# 2      No Side Effects                        menstrual cramps
# 3    Mild Side Effects                             acid reflux
# 4  Severe Side Effects                            fibromyalgia
#
#                                       benefitsReview  \
# 0  slowed the progression of left ventricular dys...
# 1  Although this type of birth control has more c...
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_24['condition'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_24, x='Unnamed: 0', y='condition', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-38-570b440232ad>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_24, x='Unnamed: 0', y='condition', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_23['sideEffects'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_23, x='Unnamed: 0', y='sideEffects', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-39-5fdf57353a92>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_23, x='Unnamed: 0', y='sideEffects', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_22['effectiveness'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_22, x='Unnamed: 0', y='effectiveness', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-40-b949df5d3335>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_22, x='Unnamed: 0', y='effectiveness', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_21['urlDrugName'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_21, x='Unnamed: 0', y='urlDrugName', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-41-7629659a6e02>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(_df_21, x='Unnamed: 0', y='urlDrugName', inner='stick', palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['benefitsReview'].value_counts()
    for x_label, grp in _df_20.groupby('condition')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('condition')
_ = plt.ylabel('benefitsReview')
# Out:
# ) missing from current font.
#   fig.canvas.draw()
# ) missing from current font.
#   func(*args, **kwargs)
# ) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['condition'].value_counts()
    for x_label, grp in _df_19.groupby('sideEffects')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('sideEffects')
_ = plt.ylabel('condition')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['sideEffects'].value_counts()
    for x_label, grp in _df_18.groupby('effectiveness')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('effectiveness')
_ = plt.ylabel('sideEffects')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['effectiveness'].value_counts()
    for x_label, grp in _df_17.groupby('urlDrugName')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('urlDrugName')
_ = plt.ylabel('effectiveness')

# %%
from matplotlib import pyplot as plt
_df_16['rating'].plot(kind='line', figsize=(8, 4), title='rating')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_15['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_14.plot(kind='scatter', x='Unnamed: 0', y='rating', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_13.groupby('condition').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_12.groupby('sideEffects').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_11.groupby('effectiveness').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_10.groupby('urlDrugName').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_9['rating'].plot(kind='hist', bins=20, title='rating')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_8['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
print(Training2['effectiveness'].unique())
# Out:
# ['Highly Effective' 'Marginally Effective' 'Ineffective'
#  'Considerably Effective' 'Moderately Effective']

# %%
print(Training2['sideEffects'].unique())
# Out:
# ['Mild Side Effects' 'Severe Side Effects' 'No Side Effects'
#  'Extremely Severe Side Effects' 'Moderate Side Effects']

# %%
mh.drop(columns=['uniqueID', 'date','usefulCount'], inplace=True)

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from matplotlib import pyplot as plt
stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, width = 1200, height = 800).generate(str(Training2['urlDrugName']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - Drug Names', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from matplotlib import pyplot as plt
stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'white', stopwords = stopwords, width = 1200, height = 800).generate(str(Training1['condition']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - Condition', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
mh1= Training2[Training2['condition'].isin(["depression","COPD, Maintenance","ADHD", "Depression","anxiety","Anxiety","Bipolar Disorde","Epilepsy","Bipolar Disorde","Panic Disorde", "Anxiety and Stress", "Major Depressive Disorde","Generalized Anxiety Disorde","Night Terrors","Post Traumatic Stress Disorde","Obsessive Compulsive Disorde","Schizoaffective Disorde","panic disorder","depression/ anxiety","depression and generalized anxiety","anxiety/ ocpd /depression","OCPD","OCD","ocd","panic attacks and depression","generalized anxiety disorder","anxiety and to avoid feeling misrable","anxiety/ mild depression","bipolar","restless sleep","sleep problem","depression/anxiety","hot flash sleep problems","depression,irritability","severe depression","depression/difficulty sleeping","insomnia","bi-polar mania with anger issues","anxiety insomnia","bipolar disorder / insomnia","depression/panic disorder","anxiety and depression","depression; intrusive suicidal impulses","fatigue","depression, ptsd fatigue","anxiety, panic attck, nervousness","irritability,anxiety","social anxiety","severe insomnia","bipolar disorder ii","bipolar i","depression, anxiety, ocd, nausea","insomnia, bipolar","fatigue,depression","insomnia, migraines","bi-polar 2","clinical depression","psychosis","Psychosis","Posttraumatic stress disorder","recurrent depression","stress-related anxiety","depression, tension headache","depression, a.d.d., mood instability","depression (atypical)","Insomnia"])]

# %%
mh1
# Out:
#       Unnamed: 0 urlDrugName  rating           effectiveness  \
# 7           2715      elavil      10  Considerably Effective
# 8           1591       xanax      10        Highly Effective
# 12           959     sarafem       8  Considerably Effective
# 15          3692  effexor-xr       8        Highly Effective
# 18          2566    klonopin       8  Considerably Effective
# ...          ...         ...     ...                     ...
# 3044        2264     lexapro       4    Moderately Effective
# 3049        1600       xanax      10        Highly Effective
# 3053          91     pristiq       8  Considerably Effective
# 3077        2305     lexapro       7    Moderately Effective
# 3103        3281      zoloft       1             Ineffective
#
#                         sideEffects                     condition  \
# 7                   No Side Effects                    depression
# 8                   No Side Effects                panic disorder
# ...

# %%
print(mh1.urlDrugName.unique())
# Out:
# ['elavil' 'xanax' 'sarafem' 'effexor-xr' 'klonopin' 'effexor' 'provigil'
#  'ambien' 'wellbutrin' 'ativan' 'prozac' 'celexa' 'lexapro' 'paxil'
#  'ambien-cr' 'wellbutrin-xl' 'wellbutrin-sr' 'xyrem' 'zoloft' 'anafranil'
#  'serzone' 'atarax' 'citalopram' 'abilify' 'valium' 'seroquel' 'baclofen'
#  'risperdal' 'climara' 'remeron' 'trazodone' 'cymbalta' 'clonazepam'
#  'adderall' 'mirtazapine' 'alprazolam' 'lunesta' 'lithium-carbonate'
#  'lamictal' 'halcion' 'sonata' 'nortriptyline' 'desyrel' 'symbyax'
#  'flexeril' 'zyprexa' 'pristiq' 'paxil-cr' 'diazepam' 'lamotrigine'
#  'emsam' 'neurontin' 'restoril' 'lorazepam' 'buspar' 'nardil' 'pamelor'
#  'doxepin' 'vistaril']

# %%
mh1.drop(columns=['sideEffectsReview','commentsReview'], inplace=True)
# Out:
# <ipython-input-7-1f9a96517335>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mh1.drop(columns=['sideEffectsReview','commentsReview'], inplace=True)

# %%
mh1.drop(mh1.columns[0], axis=1, inplace=True)
# Out:
# <ipython-input-8-aaf414532e9a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mh1.drop(mh1.columns[0], axis=1, inplace=True)

# %%
mh1
# Out:
#      urlDrugName  rating           effectiveness  \
# 7         elavil      10  Considerably Effective
# 8          xanax      10        Highly Effective
# 12       sarafem       8  Considerably Effective
# 15    effexor-xr       8        Highly Effective
# 18      klonopin       8  Considerably Effective
# ...          ...     ...                     ...
# 3044     lexapro       4    Moderately Effective
# 3049       xanax      10        Highly Effective
# 3053     pristiq       8  Considerably Effective
# 3077     lexapro       7    Moderately Effective
# 3103      zoloft       1             Ineffective
#
#                         sideEffects                     condition  \
# 7                   No Side Effects                    depression
# 8                   No Side Effects                panic disorder
# 12                Mild Side Effects                    depression
# 15                  No Side Effects                       anxiety
# ...

# %%
#drugName        condition   review  rating effectiveness  sideEffects
#df.iloc[:,[0,2,1]]
mh1.iloc[:,[0, 4, 5, 1, 2, 3]]
# Out:
#         drugName                     condition  \
# 7         elavil                    depression
# 8          xanax                panic disorder
# 12       sarafem                    depression
# 15    effexor-xr                       anxiety
# 18      klonopin  generalized anxiety disorder
# ...          ...                           ...
# 3044     lexapro                    depression
# 3049       xanax                       anxiety
# 3053     pristiq            depression/anxiety
# 3077     lexapro        anxiety and depression
# 3103      zoloft                    depression
#
#                                                  review  rating  \
# 7     Although this drug was originally prescribed f...      10
# 8     This simply just works fast and without any of...      10
# 12    I found that this drug helps significantly wit...       8
# 15    reduction in anxiety, no panic attacks.  drug ...       8
# 18    Very good at relieving anxiety.  Good at gener...       8
# ...

# %%
mh1.columns = ['drugName','rating','effectiveness','sideEffects','condition','review']

# %%
from wordcloud import WordCloud
from wordcloud import STOPWORDS
from matplotlib import pyplot as plt
stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'yellow', stopwords = stopwords, width = 1200, height = 800).generate(str(mh1['condition']))

plt.rcParams['figure.figsize'] = (10, 10)
plt.title('Word Cloud - Condition', fontsize = 25)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()

# %%
mh1.to_csv('drugLibTrain_MH1_raw.csv',index=False)

# %%
mh_depression_anxiety_panic= Training1[Training1['condition'].isin(["depression","Depression","anxiety","Anxiety","Panic Disorde", "Anxiety and Stress", "Major Depressive Disorde","Generalized Anxiety Disorde","Night Terrors","Post Traumatic Stress Disorde","Obsessive Compulsive Disorde","panic disorder","depression/ anxiety","depression and generalized anxiety","anxiety/ ocpd /depression","OCD","ocd","panic attacks and depression","generalized anxiety disorder","anxiety and to avoid feeling misrable","anxiety/ mild depression","bipolar","restless sleep","sleep problem","depression/anxiety","hot flash sleep problems","depression,irritability","severe depression","depression/difficulty sleeping","insomnia","anxiety insomnia","bipolar disorder / insomnia","depression/panic disorder","anxiety and depression","depression; intrusive suicidal impulses","depression, ptsd fatigue","anxiety, panic attck, nervousness","irritability,anxiety","social anxiety","severe insomnia","depression, anxiety, ocd, nausea","insomnia, bipolar","fatigue,depression","insomnia, migraines","clinical depression","psychosis","Posttraumatic stress disorder","recurrent depression","stress-related anxiety","depression, tension headache","depression, a.d.d., mood instability","depression (atypical)","Insomnia"])]

# %%
mh1_depression_anxiety_panic= Training2[Training2['condition'].isin(["depression","Depression","anxiety","Anxiety","Panic Disorde", "Anxiety and Stress", "Major Depressive Disorde","Generalized Anxiety Disorde","Night Terrors","Post Traumatic Stress Disorde","Obsessive Compulsive Disorde","panic disorder","depression/ anxiety","depression and generalized anxiety","anxiety/ ocpd /depression","OCD","ocd","panic attacks and depression","generalized anxiety disorder","anxiety and to avoid feeling misrable","anxiety/ mild depression","bipolar","restless sleep","sleep problem","depression/anxiety","hot flash sleep problems","depression,irritability","severe depression","depression/difficulty sleeping","insomnia","anxiety insomnia","bipolar disorder / insomnia","depression/panic disorder","anxiety and depression","depression; intrusive suicidal impulses","depression, ptsd fatigue","anxiety, panic attck, nervousness","irritability,anxiety","social anxiety","severe insomnia","depression, anxiety, ocd, nausea","insomnia, bipolar","fatigue,depression","insomnia, migraines","clinical depression","psychosis","Posttraumatic stress disorder","recurrent depression","stress-related anxiety","depression, tension headache","depression, a.d.d., mood instability","depression (atypical)","Insomnia"])]

# %%
# This barplot shows the top 20 drugs with the 10/10 rating

# Setting the Parameter
import seaborn as sns


sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh.loc[mh.rating == 10, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20])

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);

# %%
# This barplot shows the top 20 drugs with the 10/10 rating

# Setting the Parameter
import seaborn as sns


sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh1.loc[mh1.rating == 10, "urlDrugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20])

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);

# %%
# This barplot shows the Top 20 drugs with the 10/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh1.loc[mh1.rating == 10, "urlDrugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Blues_d')

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-61-e9720d69728d>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Blues_d')

# %%
# This barplot shows the Top 20 drugs with the 10/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh1.loc[mh1.rating == 10, "urlDrugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-13-5eb4b7f90726>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

# %%
# This barplot shows the Top 20 drugs with the 1/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(mh1.loc[mh1.rating == 1, "urlDrugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

sns_rating.set_title('Top 20 drugs with 1/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-60-0fdb32ba4b27>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

# %%
# A countplot of the ratings so we can see the distribution of the ratings
plt.rcParams['figure.figsize'] = [20,8]
sns.set(font_scale = 1.4, style = 'darkgrid')
fig, ax = plt.subplots(1, 2)

sns_1 = sns.countplot(mh1['rating'], palette = 'spring', order = list(range(10, 0, -1)), ax = ax[0])
sns_2 = sns.distplot(mh1['rating'], ax = ax[1])
sns_1.set_title('Count of Ratings')
sns_1.set_xlabel("Rating")

sns_2.set_title('Distribution of Ratings')
sns_2.set_xlabel("Rating")
# Out:
# <ipython-input-62-eba2edc5f721>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_1 = sns.countplot(mh1['rating'], palette = 'spring', order = list(range(10, 0, -1)), ax = ax[0])
# <ipython-input-62-eba2edc5f721>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns_2 = sns.distplot(mh1['rating'], ax = ax[1])
# Text(0.5, 0, 'Rating')

# %%
#drugName        condition  review  rating effectiveness sideEffects

# %%
data = [Training1["drugName"], Training2["urlDrugName"], Training1["condition"], Training2["condition"], Training2["rating"], Training1["rating"], Training2["effectiveness"], Training1["review"], Training2["benefitsReview"], Training2["sideEffects"], Training2["sideEffectsReview"], Training2["commentsReview"]]
headers = ["T1-Name", "T2-Name", "T1-condition", "T2-condition", "T2-rating", "T1-rating", "T2-effectiveness", "T1-review", "T2-benefits", "T2-sideEffects", "T2-sideEffectsReview","T2-comments"]
combined = pd.concat(data, axis=1, keys=headers)
print(combined.head())
print(combined.shape)
# Out:
#                     T1-Name           T2-Name                  T1-condition  \
# 0                 Valsartan         enalapril  Left Ventricular Dysfunction
# 1                Guanfacine  ortho-tri-cyclen                          ADHD
# 2                    Lybrel           ponstel                 Birth Control
# 3                Ortho Evra          prilosec                 Birth Control
# 4  Buprenorphine / naloxone            lyrica             Opiate Dependence
#
#                              T2-condition  T2-rating  T1-rating  \
# 0  management of congestive heart failure        4.0          9
# 1                        birth prevention        1.0          8
# 2                        menstrual cramps       10.0          5
# 3                             acid reflux        3.0          8
# 4                            fibromyalgia        2.0          9
#
#        T2-effectiveness                                          T1-review  \
# ...

# %%
print(combined.head(1))
# Out:
#      T1-Name    T2-Name                  T1-condition  \
# 0  Valsartan  enalapril  Left Ventricular Dysfunction
#
#                              T2-condition  T2-rating  T1-rating  \
# 0  management of congestive heart failure        4.0          9
#
#    T2-effectiveness                                          T1-review  \
# 0  Highly Effective  "It has no side effect, I take it in combinati...
#
#                                          T2-benefits     T2-sideEffects  \
# 0  slowed the progression of left ventricular dys...  Mild Side Effects
#
#                                 T2-sideEffectsReview  \
# 0  cough, hypotension , proteinuria, impotence , ...
#
#                                          T2-comments
# 0  monitor blood pressure , weight and asses for ...

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161297 entries, 0 to 161296
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   T1-Name               161297 non-null  object
#  1   T2-Name               3107 non-null    object
#  2   T1-condition          160398 non-null  object
#  3   T2-condition          3106 non-null    object
#  4   T2-rating             3107 non-null    float64
#  5   T1-rating             161297 non-null  int64
#  6   T2-effectiveness      3107 non-null    object
#  7   T1-review             161297 non-null  object
#  8   T2-benefits           3107 non-null    object
#  9   T2-sideEffects        3107 non-null    object
#  10  T2-sideEffectsReview  3105 non-null    object
#  11  T2-comments           3099 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 14.8+ MB

# %%
combined.to_csv('file.csv',index=False)

# %%
combined["drugName"] = combined["T1-Name"] + combined["T2-Name"]
combined["condition"] = combined["T1-condition"] + combined["T2-condition"]
combined["rating"] = combined["T1-rating"] + combined["T2-rating"]
combined = combined.drop(columns=["T1-Name", "T2-Name", "T1-condition", "T2-condition", "T1-rating", "T2-rating"])
combined = combined[["drugName", "condition", "rating", "T2-effectiveness", "T2-sideEffects","T1-review", "T2-benefits", "T2-sideEffectsReview", "T2-comments"]]

print(combined.shape)
print(combined.head())
# Out:
# (161297, 9)
#                          drugName  \
# 0              Valsartanenalapril
# 1      Guanfacineortho-tri-cyclen
# 2                   Lybrelponstel
# 3              Ortho Evraprilosec
# 4  Buprenorphine / naloxonelyrica
#
#                                            condition  rating  \
# 0  Left Ventricular Dysfunctionmanagement of cong...    13.0
# 1                               ADHDbirth prevention     9.0
# 2                      Birth Controlmenstrual cramps    15.0
# 3                           Birth Controlacid reflux    11.0
# 4                      Opiate Dependencefibromyalgia    11.0
#
#        T2-effectiveness       T2-sideEffects  \
# 0      Highly Effective    Mild Side Effects
# 1      Highly Effective  Severe Side Effects
# 2      Highly Effective      No Side Effects
# 3  Marginally Effective    Mild Side Effects
# 4  Marginally Effective  Severe Side Effects
#
#                                            T1-review  \
# ...

# %%
combined.to_csv('file1.csv',index=False)

# %%
combined.describe()
# Out:
#             rating
# count  3107.000000
# mean     14.028645
# std       4.429401
# min       2.000000
# 25%      11.000000
# 50%      15.000000
# 75%      18.000000
# max      20.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['rating'].plot(kind='hist', bins=20, title='rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['rating'].plot(kind='line', figsize=(8, 4), title='rating')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_0['rating'].plot(kind='hist', bins=30, title='rating')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_1['rating'].plot(kind='line', figsize=(8, 4), title='rating')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161297 entries, 0 to 161296
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   drugName              3107 non-null    object
#  1   condition             3090 non-null    object
#  2   rating                3107 non-null    float64
#  3   T2-effectiveness      3107 non-null    object
#  4   T2-sideEffects        3107 non-null    object
#  5   T1-review             161297 non-null  object
#  6   T2-benefits           3107 non-null    object
#  7   T2-sideEffectsReview  3105 non-null    object
#  8   T2-comments           3099 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 11.1+ MB

# %%
mental_health=mh
mental_health1=mh1

# %%
combined_mh = mental_health1.append(mental_health)
# Out:
# <ipython-input-29-5f9fca475a3c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_mh = mental_health1.append(mental_health)

# %%
print(combined_mh.head())
# Out:
#       drugName  rating           effectiveness        sideEffects  \
# 7       elavil      10  Considerably Effective    No Side Effects
# 8        xanax      10        Highly Effective    No Side Effects
# 12     sarafem       8  Considerably Effective  Mild Side Effects
# 15  effexor-xr       8        Highly Effective    No Side Effects
# 18    klonopin       8  Considerably Effective  Mild Side Effects
#
#                        condition  \
# 7                     depression
# 8                 panic disorder
# 12                    depression
# 15                       anxiety
# 18  generalized anxiety disorder
#
#                                                review
# 7   Although this drug was originally prescribed f...
# 8   This simply just works fast and without any of...
# 12  I found that this drug helps significantly wit...
# 15  reduction in anxiety, no panic attacks.  drug ...
# 18  Very good at relieving anxiety.  Good at gener...

# %%
combined_mh.to_csv('combinedmh.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
combined_mh=pd.read_csv('combined_health_dataset.csv')

# %%
print(combined_mh.shape)
# Out:
# (34589, 6)

# %%
# This barplot shows the Top 20 drugs with the 1/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(combined_mh.loc[combined_mh.rating == 1, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

sns_rating.set_title('Top 20 drugs with 1/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-4-85475b13096e>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

# %%
# This barplot shows the Top 20 drugs with the 10/10 rating

# Setting the Parameter
sns.set(font_scale = 1.2, style = 'darkgrid')
plt.rcParams['figure.figsize'] = [15, 8]

rating = dict(combined_mh.loc[combined_mh.rating == 10, "drugName"].value_counts())
drugname = list(rating.keys())
drug_rating = list(rating.values())

sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

sns_rating.set_title('Top 20 drugs with 10/10 rating')
sns_rating.set_ylabel("Number of Ratings")
sns_rating.set_xlabel("Drug Names")
plt.setp(sns_rating.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-5-7021c7071e8f>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_rating = sns.barplot(x = drugname[0:20], y = drug_rating[0:20], palette = 'Greens_d')

# %%
# A countplot of the ratings so we can see the distribution of the ratings
plt.rcParams['figure.figsize'] = [20,8]
sns.set(font_scale = 1.4, style = 'darkgrid')
fig, ax = plt.subplots(1, 2)

sns_1 = sns.countplot(combined_mh['rating'], palette = 'spring', order = list(range(10, 0, -1)), ax = ax[0])
sns_2 = sns.distplot(combined_mh['rating'], ax = ax[1])
sns_1.set_title('Count of Ratings')
sns_1.set_xlabel("Rating")

sns_2.set_title('Distribution of Ratings')
sns_2.set_xlabel("Rating")
# Out:
# <ipython-input-14-06875e5a9374>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns_1 = sns.countplot(combined_mh['rating'], palette = 'spring', order = list(range(10, 0, -1)), ax = ax[0])
# <ipython-input-14-06875e5a9374>:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns_2 = sns.distplot(combined_mh['rating'], ax = ax[1])
# Text(0.5, 0, 'Rating')

# %%
# lets find the Highest and Lowest Rated Drugs for each Condition
import ipywidgets as widgets
from ipywidgets import *
@interact
def high_low_rate(condition = list(combined_mh['condition'].value_counts().index)):
    print("\n Top 5 Drugs")
    print(combined_mh[combined_mh['condition'] == condition][['drugName','rating']].sort_values(by = 'rating',
                                                 ascending = False).head().reset_index(drop = True))
    print("\n\n Bottom 5 Drugs")
    print(combined_mh[combined_mh['condition'] == condition][['drugName','rating']].sort_values(by = 'rating',
                                                 ascending = True).head().reset_index(drop = True))
# Out:
# interactive(children=(Dropdown(description='condition', options=('Depression', 'Anxiety', 'Bipolar Disorde', '…

# %%
# lets check Drugs, which were useful to Highest Number of Poeple
combined_mh[['drugName','rating']][combined_mh['rating'] >
                    combined_mh['rating'].mean()].sort_values(by = 'rating',
                                        ascending = False).head(10).reset_index(drop = True)
# Out:
#        drugName  rating
# 0   Venlafaxine      10
# 1   Lamotrigine      10
# 2  Clomipramine      10
# 3    Alprazolam      10
# 4    Quetiapine      10
# 5      Klonopin      10
# 6    Gabapentin      10
# 7       Pristiq      10
# 8       Parnate      10
# 9         Xanax      10

# %%
# lets check the Most Common Conditions

print("Number of Unique Conditions :", combined_mh['condition'].nunique())
combined_mh['condition'].value_counts().head(10)
# Out:
# Number of Unique Conditions : 60
# Depression                      9069
# Anxiety                         5904
# Bipolar Disorde                 4224
# Insomnia                        3673
# ADHD                            3383
# Anxiety and Stress              1663
# Major Depressive Disorde        1607
# Panic Disorde                   1463
# Generalized Anxiety Disorde     1164
# Obsessive Compulsive Disorde     579
# Name: condition, dtype: int64

# %%
# lets check this in Graph,

popular_conditions = ('Depression', 'Anxiety','Bipolar Disorde', 'Insomnia', 'ADHD','Anxiety and Stress', 'Major Depressive Disorde','Panic Disorde','Generalized Anxiety Disorde','Obsessive Compulsive Disord')
conditions = combined_mh.loc[combined_mh['condition'].isin(popular_conditions)]

sns.barplot(x = conditions['condition'], y = conditions['rating'], hue = combined_mh['effectiveness'],
     palette = 'autumn')
plt.title('Conditions vs Effective Number of Drugs')
plt.xticks(rotation = 90)
plt.ylabel(' ')
plt.legend(loc='upper right')
plt.show()

# %%
# lets find the Highest and Lowest Rated Drugs for each Condition

@interact
def high_low_rate(condition = list(data['condition'].value_counts().index)):
    print("\n Top 5 Drugs")
    print(data[data['condition'] == condition][['drugName','usefulness']].sort_values(by = 'usefulness',
                                                 ascending = False).head().reset_index(drop = True))
    print("\n\n Bottom 5 Drugs")
    print(data[data['condition'] == condition][['drugName','usefulness']].sort_values(by = 'usefulness',
                                                 ascending = True).head().reset_index(drop = True))
